# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\us\\OneDrive\\Desktop\\regexml\\placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df['cgpa'].value_counts()
# Out:
# 6.34    2
# 8.14    2
# 6.18    2
# 5.54    2
# 6.00    2
#        ..
# 7.92    1
# 5.44    1
# 6.33    1
# 5.46    1
# 6.59    1
# Name: cgpa, Length: 89, dtype: int64

# %%
df.iloc[:5,2:]
# Out:
#    placed
# 0       1
# 1       0
# 2       1
# 3       1
# 4       1

# %%
df.loc[50,['cgpa','placed']]
# Out:
# cgpa      8.22
# placed    1.00
# Name: 50, dtype: float64

# %%
a=df.axes
a
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
a=df.dtypes
a
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty
b
# Out:
# False

# %%
i=df.ndim         #number of axes (it is 2)
i
# Out:
# 2

# %%
t=df.shape      #shape=n(row) , n(column)
t
# Out:
# (100, 3)

# %%
d=df.size           #row count * column count
d
# Out:
# 300

# %%
a=df.values           #get a numpty array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df=df.copy()

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r=df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
x=df.astype(int)       #type conversion
#x=df['cgpa'].astype(int)     #if want to change only one column data type
x
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
t=df.add(4)
#df['cgpa']=df['cgpa'].add(4)
t
# Out:
#      cgpa  resume_score  placed
# 0   12.14         10.52       5
# 1   10.17          9.17       4
# 2   12.27         12.86       5
# 3   10.88         11.27       5
# 4   11.52         11.30       5
# ..    ...           ...     ...
# 95  10.33         10.38       4
# 96  12.23         11.76       5
# 97  10.65         11.78       4
# 98  12.14          9.63       5
# 99  10.09         10.61       4
#
# [100 rows x 3 columns]

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
a=df.max()
a
# Out:
# cgpa            9.40
# resume_score    9.06
# placed          1.00
# dtype: float64

# %%
b=df.min()
b
# Out:
# cgpa            5.27
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
c=df.mean()
c
# Out:
# cgpa            6.9422
# resume_score    6.9305
# placed          0.5000
# dtype: float64

# %%
d=df.median()
d
# Out:
# cgpa            6.620
# resume_score    7.055
# placed          0.500
# dtype: float64

# %%
s=df.sum()
s
# Out:
# cgpa            694.22
# resume_score    693.05
# placed           50.00
# dtype: float64

# %%
g=df.filter(items=['cgpa','placed'])
g
# Out:
#     cgpa  placed
# 0   8.14       1
# 1   6.17       0
# 2   8.27       1
# 3   6.88       1
# 4   7.52       1
# ..   ...     ...
# 95  6.33       0
# 96  8.23       1
# 97  6.65       0
# 98  8.14       1
# 99  6.09       0
#
# [100 rows x 2 columns]

# %%
a=df.filter(items=[5,6],axis=0)
a
# Out:
#    cgpa  resume_score  placed
# 5  8.77          6.19       1
# 6  5.34          7.09       0

# %%
t=df.filter(like='5',axis=0)    #indexing value mai 5 kha kha hai vo print kerga
t
# Out:
#     cgpa  resume_score  placed
# 5   8.77          6.19       1
# 15  8.88          5.93       1
# 25  7.76          5.68       1
# 35  8.07          7.48       1
# 45  8.10          5.44       1
# 50  8.22          6.74       1
# 51  6.54          7.39       0
# 52  5.90          7.50       0
# 53  6.00          7.16       0
# 54  5.92          7.18       0
# 55  6.94          6.87       1
# 56  6.13          6.43       0
# 57  6.34          7.21       0
# 58  6.47          7.37       0
# 59  5.95          7.57       0
# 65  6.04          8.75       0
# 75  6.34          7.94       1
# 85  6.72          5.46       0
# 95  6.33          6.38       0

# %%
a=df.to_dict()
a
# Out:
# {'cgpa': {0: 8.14,
#   1: 6.17,
#   2: 8.27,
#   3: 6.88,
#   4: 7.52,
#   5: 8.77,
#   6: 5.34,
#   7: 6.56,
#   8: 6.32,
#   9: 7.69,
#   10: 6.18,
#   11: 5.44,
#   12: 6.09,
#   13: 8.5,
#   14: 7.51,
#   15: 8.88,
#   16: 8.04,
#   17: 7.81,
#   18: 5.94,
#   19: 6.75,
#   20: 5.8,
#   21: 6.53,
#   22: 6.16,
#   23: 6.05,
#   24: 8.22,
#   25: 7.76,
#   26: 6.27,
#   27: 5.51,
#   28: 7.46,
#   29: 6.19,
#   30: 7.36,
#   31: 5.92,
#   32: 5.87,
#   33: 8.43,
#   34: 8.87,
#   35: 8.07,
#   36: 8.16,
#   37: 9.05,
#   38: 6.0,
#   39: 7.5,
#   40: 8.25,
#   41: 8.68,
#   42: 6.9,
#   43: 8.21,
#   44: 5.47,
#   45: 8.1,
#   46: 5.83,
#   47: 7.05,
#   48: 5.54,
#   49: 5.46,
#   50: 8.22,
#   51: 6.54,
#   52: 5.9,
#   53: 6.0,
#   54: 5.92,
#   55: 6.94,
#   56: 6.13,
#   57: 6.34,
#   58: 6.47,
#   59: 5.95,
#   60: 5.87,
#   61: 6.89,
#   62: 5.75,
#   63: 8.65,
#   64: 7.93,
#   65: 6.04,
#   66: 8.35,
#   67: 6.59,
#   68: 6.01,
#   69: 8.06,
#   70: 7.12,
#   71: 7.34,
# ...

# %%
b=df.to_string()
b
# Out:
# '    cgpa  resume_score  placed\n0   8.14          6.52       1\n1   6.17          5.17       0\n2   8.27          8.86       1\n3   6.88          7.27       1\n4   7.52          7.30       1\n5   8.77          6.19       1\n6   5.34          7.09       0\n7   6.56          6.29       0\n8   6.32          6.71       0\n9   7.69          7.12       1\n10  6.18          6.35       0\n11  5.44          6.54       0\n12  6.09          7.01       0\n13  8.50          5.09       1\n14  7.51          6.25       1\n15  8.88          5.93       1\n16  8.04          7.64       1\n17  7.81          8.71       1\n18  5.94          5.88       0\n19  6.75          8.11       1\n20  5.80          8.06       0\n21  6.53          7.64       0\n22  6.16          5.77       0\n23  6.05          7.13       0\n24  8.22          6.18       1\n25  7.76          5.68       1\n26  6.27          6.47       0\n27  5.51          6.15       0\n28  7.46          7.67       1\n29  6.19          7.30       0\n30  7
# ...

# %%
idx=df.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label1=df.columns[0]
label1
# Out:
# 'cgpa'

# %%
p=df.columns.tolist()
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
a=df.columns.values    #array of column label
a
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
a=df.rename(columns={'cgpa':'half_yearly_mrks','resume_score':'semestr_marks'})
a
# Out:
#     half_yearly_mrks  semestr_marks  placed
# 0               8.14           6.52       1
# 1               6.17           5.17       0
# 2               8.27           8.86       1
# 3               6.88           7.27       1
# 4               7.52           7.30       1
# ..               ...            ...     ...
# 95              6.33           6.38       0
# 96              8.23           7.76       1
# 97              6.65           7.78       0
# 98              8.14           5.63       1
# 99              6.09           6.61       0
#
# [100 rows x 3 columns]

# %%
df['half']=df['cgpa'].where(df['cgpa']>50,other=0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0  8.14          6.52       1   0.0
# 1  6.17          5.17       0   0.0
# 2  8.27          8.86       1   0.0
# 3  6.88          7.27       1   0.0
# 4  7.52          7.30       1   0.0
# 5  8.77          6.19       1   0.0
# 6  5.34          7.09       0   0.0
# 7  6.56          6.29       0   0.0
# 8  6.32          6.71       0   0.0
# 9  7.69          7.12       1   0.0

# %% [markdown]
# # INSURANCE

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\us\\OneDrive\\Desktop\\regexml\\insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 18    69
# 19    68
# 20    29
# 51    29
# 45    29
# 46    29
# 47    29
# 48    29
# 50    29
# 52    29
# 28    28
# 54    28
# 21    28
# 27    28
# 26    28
# 49    28
# 25    28
# 24    28
# 23    28
# 22    28
# 53    28
# 42    27
# 44    27
# 43    27
# 41    27
# 40    27
# 31    27
# 30    27
# 29    27
# 56    26
# 34    26
# 33    26
# 32    26
# 57    26
# 55    26
# 35    25
# 59    25
# 58    25
# 36    25
# 39    25
# 38    25
# 37    25
# 60    23
# 61    23
# 62    23
# 63    23
# 64    22
# Name: age, dtype: int64

# %%
df.iloc[200:1100,3:5]
# Out:
#       children smoker
# 200          0     no
# 201          1     no
# 202          0     no
# 203          0    yes
# 204          0     no
# ...        ...    ...
# 1095         4     no
# 1096         2    yes
# 1097         0     no
# 1098         0     no
# 1099         1     no
#
# [900 rows x 2 columns]

# %%
df.loc[85,['bmi']]
# Out:
# bmi    22.895
# Name: 85, dtype: object

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# # COVID_TOY

# %%
import pandas as np
df=pd.read_csv("C:\\Users\\us\\OneDrive\\Desktop\\regexml\\covid_toy.csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df['cough'].value_counts()
# Out:
# Mild      62
# Strong    38
# Name: cough, dtype: int64

# %%
df['city'].value_counts()
# Out:
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: city, dtype: int64

# %%
df.iloc[62:98,1:4]
# Out:
#     gender  fever   cough
# 62  Female  104.0  Strong
# 63    Male  100.0    Mild
# 64    Male  104.0    Mild
# 65  Female  102.0    Mild
# 66    Male  104.0    Mild
# 67    Male   99.0    Mild
# 68  Female  104.0  Strong
# 69  Female  103.0    Mild
# 70  Female  101.0  Strong
# 71  Female  104.0  Strong
# 72  Female  101.0    Mild
# 73    Male   98.0  Strong
# 74  Female  104.0  Strong
# 75    Male  102.0    Mild
# 76    Male  100.0    Mild
# 77  Female  101.0    Mild
# 78    Male  100.0    Mild
# 79  Female  103.0    Mild
# 80  Female   99.0    Mild
# 81    Male   99.0    Mild
# 82    Male   98.0    Mild
# 83  Female  104.0    Mild
# 84  Female   98.0  Strong
# 85  Female  103.0    Mild
# 86    Male  104.0    Mild
# 87    Male  101.0  Strong
# 88  Female  100.0    Mild
# 89    Male  103.0  Strong
# 90  Female   99.0  Strong
# 91    Male    NaN    Mild
# 92  Female  102.0  Strong
# 93    Male  100.0    Mild
# 94    Male    NaN  Strong
# 95  Female  104.0    Mild
# ...

# %%
df.loc[50,['gender']]
# Out:
# gender    Male
# Name: 50, dtype: object

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
